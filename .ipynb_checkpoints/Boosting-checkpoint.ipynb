# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, validation_curve, StratifiedShuffleSplit,KFold,GridSearchCV
from sklearn.metrics import accuracy_score,fbeta_score,f1_score
import numpy as np
import matplotlib.pyplot as plt
from helpers import make_complexity_curve, make_learning_curve
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# **Load Cleaned Adult Data**

# %%
adult_df = pd.read_csv(filepath_or_buffer="adult_cleaned.csv")
adult_df_dummies = pd.get_dummies(adult_df.drop('target', 1))
adult_x = adult_df_dummies.copy().values
adult_y = adult_df["target"].copy().values
X_adult_train, X_adult_test, y_adult_train, y_adult_test = train_test_split(adult_x, adult_y, test_size=0.3,random_state=0)
print(f"adult_df: {adult_df.shape}")
print(f"X_adult_train: {X_adult_train.shape}")
print(f"X_adult_test: {X_adult_test.shape}")
print(f"y_adult_train: {y_adult_train.shape}")
print(f"y_adult_test: {y_adult_test.shape}")
# Out:
# adult_df: (30162, 15)
# X_adult_train: (21113, 104)
# X_adult_test: (9049, 104)
# y_adult_train: (21113,)
# y_adult_test: (9049,)

# %% [markdown]
# **Load Spam**

# %%
spam_df = pd.read_csv('spambase2.csv', header=0)
spam_x = spam_df.drop('class', axis=1)
spam_y = spam_df['class']
X_spam_train, X_spam_test, y_spam_train, y_spam_test = train_test_split(spam_x, spam_y, test_size=0.3,random_state=0)
print(f"X_spam_train: {X_spam_train.shape}")
print(f"X_spam_test: {X_spam_test.shape}")
print(f"y_spam_train: {y_spam_train.shape}")
print(f"y_spam_test: {y_spam_test.shape}")
# Out:
# X_spam_train: (3220, 57)
# X_spam_test: (1381, 57)
# y_spam_train: (3220,)
# y_spam_test: (1381,)

# %% [markdown]
# **GridSearch**

# %%
params = {
    'n_estimators': list(range(1, 100, 10)),
    'base_estimator__max_depth': list(np.arange(1, 50, 1)),
    'learning_rate': [0.01,0.05,0.1,0.3,1]
}

# %%
adult_cv = GridSearchCV(AdaBoostClassifier(base_estimator=DecisionTreeClassifier(random_state=123),param_grid=params, cv=5, n_estimators=100)
adult_cv.fit(X_adult_train, y_adult_train)
print(f"best params adult: {adult_cv.best_params_}")
# Out:
# best params adult: {'base_estimator__max_depth': 2, 'n_estimators': 100}

# %%
spam_cv = GridSearchCV(AdaBoostClassifier(base_estimator=DecisionTreeClassifier(random_state=123),random_state=123),param_grid=params, cv=5)
spam_cv.fit(X_spam_train, y_spam_train)
spam_cv.best_params_
print(f"best params spam: {spam_cv.best_params_}")
# Out:
# best params spam: {'base_estimator__max_depth': 18, 'n_estimators': 60}

# %%
r= pd.DataFrame(spam_cv.cv_results_)
r.iloc[177]
# Out:
# mean_fit_time                                                                1.67566
# std_fit_time                                                               0.0356483
# mean_score_time                                                            0.0137268
# std_score_time                                                           0.000373485
# param_base_estimator__max_depth                                                   18
# param_n_estimators                                                                60
# params                             {'base_estimator__max_depth': 18, 'n_estimator...
# split0_test_score                                                           0.955039
# split1_test_score                                                           0.948758
# split2_test_score                                                            0.96118
# split3_test_score                                                           0.964286
# split4_test_score                                                           0.970451
# mean_test_score                                                             0.959938
# std_test_score                                                            0.00748111
# rank_test_score                                                                    1
# split0_train_score                                                                 1
# split1_train_score                                                                 1
# split2_train_score                                                                 1
# split3_train_score                                                                 1
# split4_train_score                                                                 1
# mean_train_score                                                                   1
# std_train_score                                                                    0
# Name: 177, dtype: object

# %% [markdown]
# **Learning Curve**

# %%
make_learning_curve(adult_cv.best_estimator_,X_adult_train,y_adult_train,np.linspace(0.1, 1.0, 10),10,"boosting","adult")
# Out:
# best size: 19001

# %%
make_learning_curve(spam_cv.best_estimator_, X_spam_train, y_spam_train, np.linspace(0.1, 1.0, 10), 10, "boosting", "spam")
# Out:
# best size: 2897

# %% [markdown]
# **n_estimators**

# %%
clf = AdaBoostClassifier(base_estimator=adult_cv.best_estimator_,random_state=55)
make_complexity_curve(clf, X_adult_train, y_adult_train, "n_estimators", [1,2,5,10,20,30,45,60,80,100],5,"booster","adult")
# Out:
# Model Complexity Curve: booster - adult (n_estimators)
# best n_estimators: 60
# Complexity curve complete

# %%
clf = AdaBoostClassifier(base_estimator=spam_cv.best_estimator_,random_state=55)
make_complexity_curve(clf, X_spam_train, y_spam_train, "n_estimators", [1,2,5,10,20,30,45,60,80,100],5,"booster","spam")
# Out:
# Model Complexity Curve: booster - spam (n_estimators)
# best n_estimators: 1
# Complexity curve complete

# %% [markdown]
# **base_estimator__max_depth**

# %%
clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(),random_state=55)
make_complexity_curve(clf, X_adult_train, y_adult_train, "base_estimator__max_depth", list(np.arange(1, 50, 1)),5,"booster","adult")
# Out:
# Model Complexity Curve: booster - adult (base_estimator__max_depth)
# best base_estimator__max_depth: 2
# Complexity curve complete

# %%
clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(),random_state=55)
make_complexity_curve(clf, X_spam_train, y_spam_train, "base_estimator__max_depth", list(np.arange(1, 50, 1)),5,"booster","spam")
# Out:
# Model Complexity Curve: booster - spam (base_estimator__max_depth)
# best base_estimator__max_depth: 25
# Complexity curve complete

# %% [markdown]
# **n_estimators with max_depths**

# %%
for max_depth in range(1,11):
    clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=max_depth),random_state=55)
    make_complexity_curve(clf, X_adult_train, y_adult_train,"n_estimators",[1,2,5,10,20,30,45,60,80,100],5, f"booster_max_depth={max_depth}","adult")
# Out:
# Model Complexity Curve: booster_max_depth=1 - adult (n_estimators)
# best n_estimators: 100
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=2 - adult (n_estimators)
# best n_estimators: 100
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=3 - adult (n_estimators)
# best n_estimators: 30
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=4 - adult (n_estimators)
# best n_estimators: 20
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=5 - adult (n_estimators)
# best n_estimators: 10
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=6 - adult (n_estimators)
# best n_estimators: 5
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=7 - adult (n_estimators)
# best n_estimators: 2
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=8 - adult (n_estimators)
# best n_estimators: 2
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=9 - adult (n_estimators)
# best n_estimators: 2
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=10 - adult (n_estimators)
# best n_estimators: 2
# Complexity curve complete

# %%
for max_depth in range(1,11):
    clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=max_depth),random_state=55)
    make_complexity_curve(clf, X_titanic_train, y_titanic_train,"n_estimators",[1,2,5,10,20,30,45,60,80,100],5, f"booster_max_depth={max_depth}","titanic")
# Out:
# Model Complexity Curve: booster_max_depth=1 - titanic (n_estimators)
# best n_estimators: 10
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=2 - titanic (n_estimators)
# best n_estimators: 30
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=3 - titanic (n_estimators)
# best n_estimators: 1
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=4 - titanic (n_estimators)
# best n_estimators: 1
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=5 - titanic (n_estimators)
# best n_estimators: 1
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=6 - titanic (n_estimators)
# best n_estimators: 1
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=7 - titanic (n_estimators)
# best n_estimators: 1
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=8 - titanic (n_estimators)
# best n_estimators: 1
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=9 - titanic (n_estimators)
# best n_estimators: 30
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=10 - titanic (n_estimators)
# best n_estimators: 1
# Complexity curve complete

# %%
for max_depth in range(1,11):
    clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=max_depth),random_state=55)
    make_complexity_curve(clf, X_spam_train, y_spam_train,"n_estimators",[1,2,5,10,20,30,45,60,80,100],5, f"booster_max_depth={max_depth}","spam")
# Out:
# Model Complexity Curve: booster_max_depth=1 - spam (n_estimators)
# best n_estimators: 80
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=2 - spam (n_estimators)
# best n_estimators: 80
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=3 - spam (n_estimators)
# best n_estimators: 100
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=4 - spam (n_estimators)
# best n_estimators: 80
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=5 - spam (n_estimators)
# best n_estimators: 100
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=6 - spam (n_estimators)
# best n_estimators: 100
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=7 - spam (n_estimators)
# best n_estimators: 100
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=8 - spam (n_estimators)
# best n_estimators: 100
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=9 - spam (n_estimators)
# best n_estimators: 100
# Complexity curve complete
# Model Complexity Curve: booster_max_depth=10 - spam (n_estimators)
# best n_estimators: 100
# Complexity curve complete

# %%
clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(random_state=123),n_estimators=100)
result1 = make_complexity_curve(clf, X_adult_train, y_adult_train, 'base_estimator__max_depth', list(np.arange(1, 2, 1)), f"booster_max_depth","adult")
