# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit,KFold,GridSearchCV
from sklearn.metrics import accuracy_score,fbeta_score,f1_score
import numpy as np
import matplotlib.pyplot as plt
from helpers import make_complexity_curve, make_learning_curve,make_timing_curve,make_timing_curve_fixed, plot_result,make_timing_curve_from_param
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **Load Adult Data**

# %%
adult_df = pd.read_csv(filepath_or_buffer="adult_cleaned.csv")
adult_df_dummies = pd.get_dummies(adult_df.drop('target', 1))
adult_x = adult_df_dummies.copy().values
adult_y = adult_df["target"].copy().values
X_adult_train, X_adult_test, y_adult_train, y_adult_test = train_test_split(adult_x, adult_y, test_size=0.2,random_state=0)
print(f"adult_df: {adult_df.shape}")
print(f"X_adult_train: {X_adult_train.shape}")
print(f"X_adult_test: {X_adult_test.shape}")
print(f"y_adult_train: {y_adult_train.shape}")
print(f"y_adult_test: {y_adult_test.shape}")
print(f"y_adult_train pos: {(y_adult_train > 0).sum() / len(y_adult_train)}")
print(f"y_adult_train neg: {(y_adult_train == 0).sum() / len(y_adult_train)}")
pipeAdult = Pipeline([('Scale',StandardScaler())])
X_trans_adult_train = pipeAdult.fit_transform(X_adult_train, y_adult_train)
print(f"X_tran_adult_train: {X_trans_adult_train.shape}")
# Out:
# adult_df: (30162, 13)
# X_adult_train: (24129, 70)
# X_adult_test: (6033, 70)
# y_adult_train: (24129,)
# y_adult_test: (6033,)
# y_adult_train pos: 0.2489535413817398
# y_adult_train neg: 0.7510464586182601
# X_tran_adult_train: (24129, 70)

# %% [markdown]
# **Load Spam**

# %%
spam_df = pd.read_csv('spambase2.csv', header=0)
spam_x = spam_df.drop('class', axis=1).copy().values
spam_y = spam_df['class'].copy().values
X_spam_train, X_spam_test, y_spam_train, y_spam_test = train_test_split(spam_x, spam_y, test_size=0.2,random_state=0)
print(f"spam_df: {spam_df.shape}")
print(f"X_spam_train: {X_spam_train.shape}")
print(f"X_spam_test: {X_spam_test.shape}")
print(f"y_spam_train: {y_spam_train.shape}")
print(f"y_spam_test: {y_spam_test.shape}")
print(f"y_spam_train pos: {(y_spam_train > 0).sum() / len(y_spam_train)}")
print(f"y_spam_train neg: {(y_spam_train == 0).sum() / len(y_spam_train)}")
pipeSpam = Pipeline([('Scale',StandardScaler())])
X_trans_spam_train = pipeSpam.fit_transform(X_spam_train, y_spam_train)
print(f"X_tran_spam_train: {X_trans_spam_train.shape}")
# Out:
# spam_df: (4601, 58)
# X_spam_train: (3680, 57)
# X_spam_test: (921, 57)
# y_spam_train: (3680,)
# y_spam_test: (921,)
# y_spam_train pos: 0.38858695652173914
# y_spam_train neg: 0.6114130434782609
# X_tran_spam_train: (3680, 57)

# %% [markdown]
# **Grid Search**

# %%
params = {
    'metric':['euclidean'],
    'n_neighbors':np.arange(1,51,1),
    'weights':['uniform']
}

# %%
adult_cv = GridSearchCV(KNeighborsClassifier(),param_grid=params, cv=5)
adult_cv.fit(X_trans_adult_train.astype(float), y_adult_train.astype(float))
print(f"best params adult: {adult_cv.best_params_}")
# Out:
# best params adult: {'metric': 'euclidean', 'n_neighbors': 25, 'weights': 'uniform'}

# %%
spam_cv = GridSearchCV(KNeighborsClassifier(),param_grid=params, cv=5)
spam_cv.fit(X_trans_spam_train.astype(float), y_spam_train.astype(float))
print(f"best params spam: {spam_cv.best_params_}")
# Out:
# best params spam: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}

# %% [markdown]
# **Complexity**

# %%
knn_adult_cc = make_complexity_curve(KNeighborsClassifier(metric='euclidean', weights='uniform'), X_trans_adult_train, y_adult_train, "n_neighbors", np.arange(1,100,1),"knn_neighbors", "adult")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-358-6f9ffe041ac9> in <module>
# ----> 1 knn_adult_cc = make_complexity_curve(KNeighborsClassifier(metric='euclidean', weights='uniform'), X_trans_adult_train, y_adult_train, "n_neighbors", np.arange(1,100,1),"knn_neighbors", "adult")
#
# ~/school/cs7641/hw1/helpers.py in make_complexity_curve(clf, x, y, param_name, param_range, clf_name, dataset_name)
#      12     out = defaultdict(dict)
#      13     title = 'Model Complexity Curve: {} - {} ({})'.format(clf_name, dataset_name, param_name)
# ---> 14     train_scores, validation_scores = validation_curve(clf,x,y,param_name,param_range,cv=cv)
#      15     train_scores_mean = np.mean(train_scores, axis=1)
#      16     validation_scores_mean = np.mean(validation_scores, axis=1)
#
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in validation_curve(estimator, X, y, param_name, param_range, groups, cv, scoring, n_jobs, pre_dispatch, verbose, error_score)
#    1445         error_score=error_score)
#    1446         # NOTE do not change order of iteration to allow one time cv splitters
# -> 1447         for train, test in cv.split(X, y, groups) for v in param_range)
#    1448     out = np.asarray(out)
#    1449     n_params = len(param_range)
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     984                 self._iterating = self._original_iterator is not None
#     985
# --> 986             while self.dispatch_one_batch(iterator):
#     987                 pass
#     988
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     570         if return_train_score:
#     571             train_scores = _score(estimator, X_train, y_train, scorer,
# --> 572                                   is_multimetric)
#     573
#     574     if verbose > 2:
#
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer, is_multimetric)
#     608             score = scorer(estimator, X_test)
#     609         else:
# --> 610             score = scorer(estimator, X_test, y_test)
#     611
#     612         if hasattr(score, 'item'):
#
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/scorer.py in _passthrough_scorer(estimator, *args, **kwargs)
#     226 def _passthrough_scorer(estimator, *args, **kwargs):
#     227     """Function that wraps estimator.score"""
# --> 228     return estimator.score(*args, **kwargs)
#     229
#     230
#
# /usr/local/lib/python3.6/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     286         """
#     287         from .metrics import accuracy_score
# --> 288         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     289
#     290
#
# /usr/local/lib/python3.6/site-packages/sklearn/neighbors/classification.py in predict(self, X)
#     147         X = check_array(X, accept_sparse='csr')
#     148
# --> 149         neigh_dist, neigh_ind = self.kneighbors(X)
#     150         classes_ = self.classes_
#     151         _y = self._y
#
# /usr/local/lib/python3.6/site-packages/sklearn/neighbors/base.py in kneighbors(self, X, n_neighbors, return_distance)
#     441                 delayed_query(
#     442                     X[s], n_neighbors, return_distance)
# --> 443                 for s in gen_even_slices(X.shape[0], n_jobs)
#     444             )
#     445         else:
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     981             # remaining jobs.
#     982             self._iterating = False
# --> 983             if self.dispatch_one_batch(iterator):
#     984                 self._iterating = self._original_iterator is not None
#     985
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# KeyboardInterrupt:

# %%
knn_adult_cc.plot()

# %%
knn_spam_cc = make_complexity_curve(KNeighborsClassifier(metric='euclidean', weights='uniform'), X_trans_spam_train, y_spam_train, "n_neighbors", np.arange(1,51,1),"knn_neighbors", "spam")

# %%
knn_spam_cc.plot(title=knn_spam_cc.name)

# %% [markdown]
# **Timing curve**

# %%
adult_timing = make_timing_curve_fixed(adult_cv.best_estimator_.set_params(**{'algorithm': 'brute'}),X_trans_adult_train, y_adult_train,'knn_timing', 'adult')

# %%
adult_timing.plot(title=adult_timing.name)

# %%
spam_timing = make_timing_curve_fixed(spam_cv.best_estimator_.set_params(**{'algorithm': 'brute'}),X_trans_spam_train, y_spam_train,'knn_timing', 'spam')

# %%
spam_timing.plot(title=spam_timing.name)

# %% [markdown]
# **Learning curve**

# %%
adult_lc = make_learning_curve(adult_cv.best_estimator_,X_trans_adult_train.astype(float), y_adult_train.astype(float),np.linspace(0.1, 1.0, 10),'knn learning curve', 'adult')

# %%
adult_lc.plot(title=adult_lc.name)

# %%
spam_lc = make_learning_curve(spam_cv.best_estimator_,X_trans_spam_train.astype(float), y_spam_train.astype(float),np.linspace(0.1, 1.0, 10),'knn learning curve', 'spam')

# %%
spam_lc.plot(title=spam_lc.name)

# %%
adult_cv.score(pipeAdult.transform(X_adult_test),y_adult_test)
# Out:
# [autoreload of pandas failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/__init__.py", line 40, in <module>
#     from pandas.sparse.api import *
#   File "/usr/local/lib/python3.6/site-packages/pandas/sparse/api.py", line 3, in <module>
#     from pandas.sparse.array import SparseArray
#   File "/usr/local/lib/python3.6/site-packages/pandas/sparse/array.py", line 30, in <module>
#     import pandas.core.algorithms as algos
# AttributeError: module 'pandas' has no attribute 'core'
# ]
# [autoreload of numpy failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/numpy/__init__.py", line 152, in <module>
#     test = testing.nosetester._numpy_tester().test
# NameError: name 'testing' is not defined
# ]
# [autoreload of numpy.lib failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/numpy/lib/__init__.py", line 31, in <module>
#     __all__ += type_check.__all__
# NameError: name 'type_check' is not defined
# ]
# [autoreload of numpy.core.arrayprint failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _array2string() requires a code object with 3 free vars, not 0
# ]
# [autoreload of numpy.testing failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/numpy/testing/__init__.py", line 15, in <module>
#     test = nosetester._numpy_tester().test
# NameError: name 'nosetester' is not defined
# ]
# [autoreload of numpy.matrixlib failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/numpy/matrixlib/__init__.py", line 8, in <module>
#     __all__ = defmatrix.__all__
# NameError: name 'defmatrix' is not defined
# ]
# [autoreload of numpy.lib.scimath failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/numpy/lib/scimath.py", line 21, in <module>
#     import numpy.core.numerictypes as nt
# AttributeError: module 'numpy.core' has no attribute 'numerictypes'
# ]
# [autoreload of numpy.lib.npyio failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/numpy/lib/npyio.py", line 15, in <module>
#     from ._iotools import (
# ImportError: cannot import name '_bytes_to_name'
# ]
# [autoreload of numpy.polynomial.polynomial failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 277, in update_class
#     if old_obj == new_obj:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ]
# [autoreload of numpy.polynomial.chebyshev failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 277, in update_class
#     if old_obj == new_obj:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ]
# [autoreload of numpy.polynomial.legendre failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 277, in update_class
#     if old_obj == new_obj:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ]
# [autoreload of numpy.polynomial.hermite failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 277, in update_class
#     if old_obj == new_obj:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ]
# [autoreload of numpy.polynomial.hermite_e failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 277, in update_class
#     if old_obj == new_obj:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ]
# [autoreload of numpy.polynomial.laguerre failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 277, in update_class
#     if old_obj == new_obj:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ]
# [autoreload of numpy.ma.core failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/numpy/ma/core.py", line 37, in <module>
#     import numpy.core.numerictypes as ntypes
# AttributeError: module 'numpy.core' has no attribute 'numerictypes'
# ]
# [autoreload of pandas.core.config_init failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/config_init.py", line 14, in <module>
#     import pandas.core.config as cf
# AttributeError: module 'pandas.core' has no attribute 'config'
# ]
# [autoreload of pandas.core.api failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.categorical import Categorical
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/categorical.py", line 29, in <module>
#     from pandas.core.base import (PandasObject, PandasDelegate,
# ImportError: cannot import name 'PandasDelegate'
# ]
# [autoreload of pandas.core.algorithms failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/algorithms.py", line 9, in <module>
#     from pandas import compat, lib, tslib, _np_version_under1p8
# ImportError: cannot import name '_np_version_under1p8'
# ]
# [autoreload of pandas.core.base failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/base.py", line 13, in <module>
#     import pandas.core.nanops as nanops
# AttributeError: module 'pandas.core' has no attribute 'nanops'
# ]
# [autoreload of pandas.core.nanops failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: nanargmax() requires a code object with 2 free vars, not 0
# ]
# [autoreload of pandas.core.index failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/index.py", line 2, in <module>
#     from pandas.indexes.api import *
#   File "/usr/local/lib/python3.6/site-packages/pandas/indexes/api.py", line 1, in <module>
#     from pandas.indexes.base import (Index, _new_Index,  # noqa
#   File "/usr/local/lib/python3.6/site-packages/pandas/indexes/base.py", line 41, in <module>
#     from pandas.core.base import (PandasObject, FrozenList, FrozenNDArray,
# ImportError: cannot import name 'FrozenList'
# ]
# [autoreload of pandas.tseries.offsets failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/tseries/offsets.py", line 1927, in <module>
#     _int_to_month = tslib._MONTH_ALIASES
#   File "/usr/local/lib/python3.6/site-packages/pandas/util/_depr_module.py", line 86, in __getattr__
# AttributeError: 'dict' object has no attribute '__module__'
# ]
# [autoreload of pandas.tseries.frequencies failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/tseries/frequencies.py", line 15, in <module>
#     import pandas.core.algorithms as algos
# AttributeError: module 'pandas.core' has no attribute 'algorithms'
# ]
# [autoreload of pandas.core.ops failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/ops.py", line 20, in <module>
#     import pandas.core.missing as missing
# AttributeError: module 'pandas.core' has no attribute 'missing'
# ]
# [autoreload of pandas.core.strings failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/strings.py", line 17, in <module>
#     from pandas.core.base import AccessorProperty, NoNewAttributesMixin
# ImportError: cannot import name 'AccessorProperty'
# ]
# [autoreload of pandas.core.frame failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/frame.py", line 73, in <module>
#     from pandas.core.categorical import Categorical
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/categorical.py", line 29, in <module>
#     from pandas.core.base import (PandasObject, PandasDelegate,
# ImportError: cannot import name 'PandasDelegate'
# ]
# [autoreload of pandas.core.generic failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/generic.py", line 39, in <module>
#     import pandas.core.indexing as indexing
# AttributeError: module 'pandas.core' has no attribute 'indexing'
# ]
# [autoreload of pandas.core.indexing failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/indexing.py", line 20, in <module>
#     import pandas.core.common as com
# AttributeError: module 'pandas.core' has no attribute 'common'
# ]
# [autoreload of pandas.core.internals failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/internals.py", line 46, in <module>
#     import pandas.core.algorithms as algos
# AttributeError: module 'pandas.core' has no attribute 'algorithms'
# ]
# [autoreload of pandas.core.series failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/series.py", line 50, in <module>
#     from pandas.core.categorical import Categorical, CategoricalAccessor
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/categorical.py", line 29, in <module>
#     from pandas.core.base import (PandasObject, PandasDelegate,
# ImportError: cannot import name 'PandasDelegate'
# ]
# [autoreload of matplotlib failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/__init__.py", line 1309, in <module>
#     use(os.environ['MPLBACKEND'])
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/__init__.py", line 1289, in use
#     tb=matplotlib.backends._backend_loading_tb),
# AttributeError: module 'matplotlib' has no attribute 'backends'
# ]
# [autoreload of matplotlib.cbook failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: unicode_safe() requires a code object with 3 free vars, not 0
# ]
# [autoreload of matplotlib.dates failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _replace_common_substr() requires a code object with 3 free vars, not 0
# ]
# [autoreload of matplotlib.ticker failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: closeto() requires a code object with 3 free vars, not 0
# ]
# [autoreload of matplotlib.transforms failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 277, in update_class
#     if old_obj == new_obj:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ]
# [autoreload of pandas.core.window failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/window.py", line 31, in <module>
#     import pandas.core.common as com
# AttributeError: module 'pandas.core' has no attribute 'common'
# ]
# [autoreload of pandas.core.panel failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/panel.py", line 18, in <module>
#     import pandas.core.common as com
# AttributeError: module 'pandas.core' has no attribute 'common'
# ]
# [autoreload of pandas.tseries.api failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/tseries/api.py", line 7, in <module>
#     from pandas.tseries.index import DatetimeIndex, date_range, bdate_range
#   File "/usr/local/lib/python3.6/site-packages/pandas/tseries/index.py", line 32, in <module>
#     from pandas.indexes.base import _index_shared_docs
#   File "/usr/local/lib/python3.6/site-packages/pandas/indexes/base.py", line 41, in <module>
#     from pandas.core.base import (PandasObject, FrozenList, FrozenNDArray,
# ImportError: cannot import name 'FrozenList'
# ]
# [autoreload of pandas.tools.plotting failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/tools/plotting.py", line 28, in <module>
#     from pandas.tseries.period import PeriodIndex
#   File "/usr/local/lib/python3.6/site-packages/pandas/tseries/period.py", line 25, in <module>
#     import pandas.tseries.frequencies as frequencies
# AttributeError: module 'pandas.tseries' has no attribute 'frequencies'
# ]
# [autoreload of pandas.io.parsers failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/io/parsers.py", line 37, in <module>
#     import pandas.parser as _parser
#   File "pandas/parser.pyx", line 43, in init pandas.parser (pandas/parser.c:48043)
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/categorical.py", line 29, in <module>
#     from pandas.core.base import (PandasObject, PandasDelegate,
# ImportError: cannot import name 'PandasDelegate'
# ]
# [autoreload of pandas.io.excel failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/io/excel.py", line 21, in <module>
#     from pandas.tseries.period import Period
#   File "/usr/local/lib/python3.6/site-packages/pandas/tseries/period.py", line 25, in <module>
#     import pandas.tseries.frequencies as frequencies
# AttributeError: module 'pandas.tseries' has no attribute 'frequencies'
# ]
# [autoreload of pandas.io.pytables failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/io/pytables.py", line 28, in <module>
#     from pandas import (Series, DataFrame, Panel, Panel4D, Index,
# ImportError: cannot import name 'Panel4D'
# ]
# [autoreload of pandas.io.stata failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/io/stata.py", line 22, in <module>
#     from pandas.core.categorical import Categorical
#   File "/usr/local/lib/python3.6/site-packages/pandas/core/categorical.py", line 29, in <module>
#     from pandas.core.base import (PandasObject, PandasDelegate,
# ImportError: cannot import name 'PandasDelegate'
# ]
# [autoreload of pandas.compat.pickle_compat failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: find_class() requires a code object with 1 free vars, not 0
# ]
# [autoreload of pandas.io.packers failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/pandas/io/packers.py", line 59, in <module>
#     from pandas.sparse.api import SparseSeries, SparseDataFrame
#   File "/usr/local/lib/python3.6/site-packages/pandas/sparse/api.py", line 3, in <module>
#     from pandas.sparse.array import SparseArray
#   File "/usr/local/lib/python3.6/site-packages/pandas/sparse/array.py", line 30, in <module>
#     import pandas.core.algorithms as algos
# AttributeError: module 'pandas.core' has no attribute 'algorithms'
# ]
# [autoreload of pandas.io.gbq failed: Traceback (most recent call last):
# ...
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __repr__() requires a code object with 1 free vars, not 0
# ]
# [autoreload of matplotlib.texmanager failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: make_ps() requires a code object with 3 free vars, not 0
# ]
# [autoreload of matplotlib.backend_bases failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: onRemove() requires a code object with 3 free vars, not 0
# ]
# [autoreload of matplotlib.container failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: set_remove_method() requires a code object with 3 free vars, not 0
# ]
#
# Bad key "animation.mencoder_path" on line 509 in
# /usr/local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "animation.mencoder_args" on line 512 in
# /usr/local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "animation.mencoder_path" on line 511 in
# /usr/local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "animation.mencoder_args" on line 514 in
# /usr/local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# [autoreload of matplotlib.figure failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/figure.py", line 253, in <module>
#     class Figure(Artist):
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/figure.py", line 1565, in Figure
#     @docstring.dedent_interpd
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/docstring.py", line 118, in dedent_interpd
#     return interpd(dedent(func))
# KeyError: 'Axes'
# ]
# [autoreload of matplotlib.axes._axes failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py", line 94, in <module>
#     class Axes(_AxesBase):
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py", line 4694, in Axes
#     @docstring.dedent_interpd
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/docstring.py", line 118, in dedent_interpd
#     return interpd(dedent(func))
# KeyError: 'barbs_doc'
# ]
# [autoreload of matplotlib.mlab failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: logspace() requires a code object with 3 free vars, not 0
# ]
# [autoreload of matplotlib.table failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 0
# ]
# [autoreload of matplotlib.tri.triinterpolate failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 277, in update_class
#     if old_obj == new_obj:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ]
# [autoreload of matplotlib.axis failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 305, in update_property
#     update_generic(old.fget, new.fget)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: unit_data() requires a code object with 3 free vars, not 0
# ]
# [autoreload of matplotlib.spines failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_window_extent() requires a code object with 1 free vars, not 0
# ]
# [autoreload of matplotlib.projections.polar failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 0
# ]
# [autoreload of matplotlib.backends failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     module = reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 12, in <module>
#     backend = matplotlib.get_backend()
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/__init__.py", line 1387, in get_backend
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/__init__.py", line 890, in __getitem__
#     default matplotlib rc file.
# AttributeError: module 'matplotlib.rcsetup' has no attribute '_auto_backend_sentinel'
# ]
# [autoreload of matplotlib.backends.backend_agg failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 390, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 329, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: draw() requires a code object with 1 free vars, not 0
# ]
# 0.8282778054036135

# %%
adult_cv.predict(pipeAdult.transform(X_adult_test)).shape
# Out:
# (6033,)

# %%
adult_cv.score(pipeAdult.transform(X_adult_test),y_adult_test)
# Out:
# 0.8282778054036135
